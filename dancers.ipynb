# %%
# %run yagp_scraper.py

# %%
links_df, winners_df = scrape_yagp_winners(2000, 2026, headless=True)

links_df.to_csv("yagp_year_links_2000_2026.csv", index=False)
winners_df.to_csv("yagp_winners_people_only_2000_2026.csv", index=False)

print(winners_df.head(20))
# Out:
# ...
#
# Collected links:
# Empty DataFrame
# Columns: []
# Index: []
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 links_df, winners_df = scrape_yagp_winners(2000, 2026, headless=True)
#       3 links_df.to_csv("yagp_year_links_2000_2026.csv", index=False)
#       4 winners_df.to_csv("yagp_winners_people_only_2000_2026.csv", index=False)
#
# File ~\Downloads\YAGP-Awards-2000-2030\yagp_scraper.py:253, in scrape_yagp_winners(start_year, end_year, headless)
#     251 print("\nCollected links:")
#     252 print(links_df.head(20))
# --> 253 print(f"\nTotal unique links: {links_df['detail_url'].nunique()}")
#     255 all_pages = []
#     256 for url in links_df["detail_url"].dropna().unique():
#
# File c:\Users\bdion\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
# ...
