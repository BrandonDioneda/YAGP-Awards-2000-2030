# %%
import altair as alt

# %%
# %run cleanup.ipynb
# Out:
# COPPELIA PAS DE DEUX
# DON QUIXOTE PAS DE DEUX
# ALEXANDRIA MARX
# RACHEL ROHRICH
# HARLEQUINADE PAS DE DEUX
# SILVI LYBBERT
# JESLYN CHEN
# SWAN LAKE PAS DE TROIS
# ORLANDO BALLET SCHOOL FL
# MASUMI YOSHIMOTO
# PAS DE DEUX GRAND PAS CLASSIQUE
# ODALISQUES LE CORSAIRE
# RYLAND ACREE III
# LAUREN LEB
# GENEVIEVE COOVREY
# JASMINE JIMISON
# ALL AMERICAN CLASSICAL BALLET SCHOOL FL
# ['JIOH KIM 김지오' 'SIWOO JEONG 정시우' 'YUNJIN BAE 배윤진' 'JUMYEONG JANG 장주명'
#  'JAEMYEONG JANG 장재명' 'SUNGYEON HONG 홍성연' 'SHIJEAN KIM 김시진'
#  'SEOHYUN KIM 김서현' 'SEOYEON JEONG 정서연' 'GINA CHOI 최기나' 'NURI PARK 박누리'
#  'SIHU BAN 반시후' 'HYEWON KANG 강혜원' 'SUNGMIN KIM 김성민' 'DOEUN KIM 김도은'
#  'NAYEON KIM 김나연' 'BOYOUNG KIM 김보영' 'JIHYEONG CHOI 최지형' 'JIYOUNG KIM 김지영'
#  'JIYU KWON 권지유' 'ALL ENSEMBLES' 'NOWHERE TOGETHER' 'WHISPER IN MY EAR']

# %%
dancers.drop(columns={"classification"}, inplace=True)

# %%
len(dancers.Name.unique())
# Out:
# 14301

# %%
# for i in sorted(dancers.Name.unique()):
#     print(i)

# %%
dancers["Name"].value_counts()
# Out:
# Name
# CAITLYN DIONEDA    36
# KATIA ALMAYEVA     33
# AURORA KELLOGG     30
# KATE THOMAS        28
# NICOLE DENNEY      28
#                    ..
# CAROLINE FAYAD      1
# DELANEY RUSTAY      1
# EMMA TSE            1
# HALINA MANALO       1
# AVA PETLICK         1
# Name: count, Length: 14301, dtype: int64

# %%
dancers.groupby(["Year", "Name"])["Award"].count()
# Out:
# Year  Name
# 2000  ADRIANNA BROAD             1
#       ADRIANNA DE VITRE          1
#       AIMI TOYAMA                1
#       ALEXANDRA TAYLOR           1
#       ALEXI AGDEPPA              1
#                                 ..
# 2026  ZUOYI DU                   4
#       ÀUREA GÓMIZ VILLAESCUSA    7
#       ÁLVARO VALERO BERNAL       3
#       ÉMILIE LAVOIE              2
#       ÍRIS RODRIGUES             1
# Name: Award, Length: 21248, dtype: int64
